# %%
import pandas as pd
tb = pd.read_csv('tb.csv')
tb.head()
# Out:
#   iso2  year  new_sp  new_sp_m04  new_sp_m514  new_sp_m014  new_sp_m1524  \
# 0   AD  1989     NaN         NaN          NaN          NaN           NaN
# 1   AD  1990     NaN         NaN          NaN          NaN           NaN
# 2   AD  1991     NaN         NaN          NaN          NaN           NaN
# 3   AD  1992     NaN         NaN          NaN          NaN           NaN
# 4   AD  1993    15.0         NaN          NaN          NaN           NaN
#
#    new_sp_m2534  new_sp_m3544  new_sp_m4554  ...  new_sp_f04  new_sp_f514  \
# 0           NaN           NaN           NaN  ...         NaN          NaN
# 1           NaN           NaN           NaN  ...         NaN          NaN
# 2           NaN           NaN           NaN  ...         NaN          NaN
# 3           NaN           NaN           NaN  ...         NaN          NaN
# 4           NaN           NaN           NaN  ...         NaN          NaN
#
#    new_sp_f014  new_sp_f1524  new_sp_f2534  new_sp_f3544  new_sp_f4554  \
# ...

# %%
tb = tb.drop(['new_sp'], axis=1)
tb.columns = tb.columns.str.replace("new_sp_", "")
tb.columns = tb.columns.str.replace("iso2", "country")
tb = pd.melt(tb, id_vars=["country","year"], value_name="cases", var_name="sexAge")
tb.head()
# Out:
#   country  year sexAge  cases
# 0      AD  1989    m04    NaN
# 1      AD  1990    m04    NaN
# 2      AD  1991    m04    NaN
# 3      AD  1992    m04    NaN
# 4      AD  1993    m04    NaN

# %%
tmp = tb["sexAge"].str.extract("(\D)(\d+)(\d{2})")
tmp.columns = ["sex", "lowerBound", "upperBound"]
tmp["age"] = tmp["lowerBound"] + "-" + tmp["upperBound"]

# %%
tb = pd.concat([tb, tmp], axis=1)
tb = tb.drop(['sexAge',"lowerBound","upperBound"], axis=1)
tb = tb.dropna()
tb = tb[['country','year','sex','age','cases']]
tb.sort_values(by=['country'])
# Out:
#        country  year sex    age   cases
# 5784        AD  2005   m   5-14     0.0
# 75011       AD  2004   f  15-24     0.0
# 75010       AD  2003   f  15-24     1.0
# 75009       AD  2002   f  15-24     1.0
# 75006       AD  1999   f  15-24     0.0
# 75004       AD  1997   f  15-24     1.0
# 75003       AD  1996   f  15-24     1.0
# 92310       AD  1996   f  45-54     0.0
# 92311       AD  1997   f  45-54     0.0
# 92313       AD  1999   f  45-54     0.0
# 92316       AD  2002   f  45-54     0.0
# 92317       AD  2003   f  45-54     0.0
# 92318       AD  2004   f  45-54     0.0
# 92319       AD  2005   f  45-54     0.0
# 75012       AD  2005   f  15-24     1.0
# 92320       AD  2006   f  45-54     1.0
# 92322       AD  2008   f  45-54     1.0
# 69246       AD  2008   f   0-14     0.0
# 69244       AD  2006   f   0-14     0.0
# 69243       AD  2005   f   0-14     0.0
# 69242       AD  2004   f   0-14     0.0
# 69241       AD  2003   f   0-14     0.0
# ...
